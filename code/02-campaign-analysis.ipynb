# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
campaign_data = pd.read_csv('./../data-workfile/campaign_performance.csv', index_col='Unnamed: 0').drop(columns='index')
campaign_data.head()
# Out:
#   hotel_id        date utm_source utm_medium utm_campaign  user_count_website  \
# 0  hotel_1  2024-09-18     direct  (not set)     (direct)               253.0
# 1  hotel_1  2024-09-18     direct  (not set)    (not set)                 3.0
# 2  hotel_1  2024-09-18     google        cpc    (not set)               259.0
# 3  hotel_1  2024-09-18     google        cpc    (organic)                17.0
# 4  hotel_1  2024-09-18     google        cpc  campaign_15                99.0
#
#    session_count_website utm_source_cpc  user_count_datepicker  \
# 0                  304.0         no_cpc                  104.0
# 1                    4.0         no_cpc                    0.0
# 2                  273.0         google                   59.0
# 3                   21.0         google                    6.0
# 4                  105.0         google                   18.0
#
#    session_count_datepicker
# 0                     124.0
# 1                       0.0
# 2                      59.0
# ...

# %%
# Aggregate metrics by utm_source, utm_medium, or utm_campaign: \text{CTR} = \frac{\text{user_count}}{\text{session_count}} This helps identify campaigns or channels driving traffic.
